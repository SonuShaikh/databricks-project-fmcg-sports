# %%
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema   = 'gold'

dbutils.widgets.text('catlog','fmcg')
dbutils.widgets.text('data_source','customers')

catalog = dbutils.widgets.get('catlog')
data_source = dbutils.widgets.get('data_source')
s3_bucket = 's3://databricks-project-sonu/'

# city mapping
clean_city = [
    ("Bengalore", "Bengalore"),
    ("Bengaluru", "Bengalore"),
    ("Bengaluruu", "Bengalore"),

    ("Hyderabad", "Hyderabad"),
    ("Hyderabadd", "Hyderabad"),
    ("Hyderbad", "Hyderabad"),

    ("New Delhi", "New Delhi"),
    ("NewDelhee", "New Delhi"),
    ("NewDelhi", "New Delhi"),
    ("NewDheli", "New Delhi")
]
